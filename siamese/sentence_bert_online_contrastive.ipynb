# %% [markdown]
# # Siamese Network with BERT Pooling: Online Contrastive Loss Function
#
# - We train our siamese network with the training data from SemEval 2014.
# - We use the **online contrastive loss function**.
# - We then run k-NN search with test queries (previously generated for BM25) to produce test query results.

# %% [markdown]
# ## Google Colab setups
#
# This part only gets executed if this notebook is being run under Google Colab. **Please change the working path  directory below in advance!**

# %%
# Use Google Colab
use_colab = True

# Is this notebook running on Colab?
# If so, then google.colab package (github.com/googlecolab/colabtools)
# should be available in this environment

# Previous version used importlib, but we could do the same thing with
# just attempting to import google.colab
try:
    from google.colab import drive
    colab_available = True
except:
    colab_available = False

if use_colab and colab_available:
    drive.mount('/content/drive')
    
    # If there's a package I need to install separately, do it here
    #!pip install sentence-transformers==0.3.9 transformers==3.4.0

    # cd to the appropriate working directory under my Google Drive
    # %cd '/content/drive/My Drive/CS646_Final_Project/Siamese'
    
    # List the directory contents
    # !ls
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1zyXK0VOQZwuIfSaMkgJTmwtvSpUOQ1zm/CS646_Final_Project/Siamese
# requirements.txt
# sbert_bert_ada_joint_contrastive
# sbert_bert_ada_joint_online_contrastive
# sbert_bert_ada_joint_partially_correct_cosine
# sbert_bert_ada_joint_partially_correct_softmax
# sentence_bert_contrastive.ipynb
# sentence_bert_cosine.ipynb
# sentence_bert_online_contrastive.ipynb
# sentence_bert_softmax.ipynb
# Siamese_results

# %% [markdown]
# ## PyTorch GPU setup

# %%
# torch.device / CUDA Setup
import torch

use_cuda = True
use_colab_tpu = False
colab_tpu_available = False

if use_colab_tpu:
    try:
        assert os.environ['COLAB_TPU_ADDR']
        colab_tpu_available = True
    except:
        colab_tpu_available = True

if use_cuda and torch.cuda.is_available():
    torch_device = torch.device('cuda')

    # Set this to True to make your output immediately reproducible
    # Note: https://pytorch.org/docs/stable/notes/randomness.html
    torch.backends.cudnn.deterministic = False
    
    # Disable 'benchmark' mode: Set this False if you want to measure running times more fairly
    # Note: https://discuss.pytorch.org/t/what-does-torch-backends-cudnn-benchmark-do/5936
    torch.backends.cudnn.benchmark = True
    
    # Faster Host to GPU copies with page-locked memory
    use_pin_memory = True 

    # CUDA libraries version information
    print("CUDA Version: " + str(torch.version.cuda))
    print("cuDNN Version: " + str(torch.backends.cudnn.version()))
    print("CUDA Device Name: " + str(torch.cuda.get_device_name()))
    print("CUDA Capabilities: "+ str(torch.cuda.get_device_capability()))

elif use_colab_tpu and colab_tpu_available:
    # This needs to be installed separately
    # https://github.com/pytorch/xla/blob/master/contrib/colab/getting-started.ipynb
    import torch_xla 
    import torch_xla.core.xla_model as xm

    torch_device = xm.xla_device()

else:
    torch_device = torch.device('cpu')
    use_pin_memory = False
# Out:
# CUDA Version: 10.1
# cuDNN Version: 7603
# CUDA Device Name: Tesla T4
# CUDA Capabilities: (7, 5)

# %% [markdown]
# ## Import packages

# %%
import os
import random
import json
import pathlib

import sentence_transformers
from sentence_transformers import losses
import numpy as np
import jsonlines

# %%
# Random seed settings
random_seed = 646
random.seed(random_seed) # Python
np.random.seed(random_seed) # NumPy
torch.manual_seed(random_seed) # PyTorch

# %% [markdown]
# ## Load the dataset

# %%
# 0-1 label (for contrastive loss)
with open(os.path.join('.', 'data', 'our_datasets', 'laptop_train.json')) as laptop_train_file:
    laptop_train = json.load(laptop_train_file)

with open(os.path.join('.', 'data', 'our_datasets', 'restaurant_train.json')) as restaurants_train_file:
    restaurants_train = json.load(restaurants_train_file)

# %% [markdown]
# ### Training set: Joint = Laptop + Restaurants

# %%
train_combined_examples = []

for row in laptop_train:
    example = sentence_transformers.InputExample(
        texts=[row['query'][0] + ', ' + row['query'][1], row['doc']], label=row['label'])
    
    train_combined_examples.append(example)

for row in restaurants_train:
    example = sentence_transformers.InputExample(
        texts=[row['query'][0] + ', ' + row['query'][1], row['doc']], label=row['label'])
    
    train_combined_examples.append(example)

# %%
print(train_combined_examples[0])
# Out:
# <InputExample> label: 1, texts: functions, positive; The Macbook arrived in a nice twin packing and sealed in the box, all the functions works great.

# %% [markdown]
# ## Siamese Network with BERT Pooling (SBERT) Model
#
# - We use the pretrained weights released by the BERT-ADA authors.
# - Please download and extract them to the same directory as this notebook: https://github.com/deepopinion/domain-adapted-atsc#release-of-bert-language-models-finetuned-on-a-specific-domain
#     - **NOTE**: Because BERT-ADA was trained with an older version of `transformers`, you need to add `"model_type": "bert"` to `config.json`.

# %%
# Load the pretrained BERT-ADA model
# Extract the tar.xz file
#!tar -xf laptops_and_restaurants_2mio_ep15.tar.xz

pretrained_model_name = 'laptops_and_restaurants_2mio_ep15'

# %%
sbert_new_model_name = 'sbert_bert_ada_joint_online_contrastive'

# %%
word_embedding_model = sentence_transformers.models.Transformer(
    pretrained_model_name, max_seq_length=256)

pooling_model = sentence_transformers.models.Pooling(
    word_embedding_model.get_word_embedding_dimension())

model = sentence_transformers.SentenceTransformer(
    modules=[word_embedding_model, pooling_model])

# %% [markdown]
# ### Training

# %%
# PyTorch DataLoader
train_dataset = sentence_transformers.SentencesDataset(train_combined_examples, model)
train_dataloader = torch.utils.data.DataLoader(train_dataset, shuffle=True, batch_size=16)

# Loss function
# Tuples of (DataLoader, LossFunction)
train_online_contrastive_loss = (train_dataloader, losses.OnlineContrastiveLoss(model))

# Tune the model
model.fit(
    train_objectives=[train_online_contrastive_loss], 
    epochs=20,
    warmup_steps=300,
    weight_decay=0.01,
    use_amp=True)
# Out:
# HBox(children=(HTML(value='Epoch'), FloatProgress(value=0.0, max=20.0), HTML(value='')))
# HBox(children=(HTML(value='Iteration'), FloatProgress(value=0.0, max=725.0), HTML(value='')))
# HBox(children=(HTML(value='Iteration'), FloatProgress(value=0.0, max=725.0), HTML(value='')))
# HBox(children=(HTML(value='Iteration'), FloatProgress(value=0.0, max=725.0), HTML(value='')))
# HBox(children=(HTML(value='Iteration'), FloatProgress(value=0.0, max=725.0), HTML(value='')))
# HBox(children=(HTML(value='Iteration'), FloatProgress(value=0.0, max=725.0), HTML(value='')))
# HBox(children=(HTML(value='Iteration'), FloatProgress(value=0.0, max=725.0), HTML(value='')))
# HBox(children=(HTML(value='Iteration'), FloatProgress(value=0.0, max=725.0), HTML(value='')))
# HBox(children=(HTML(value='Iteration'), FloatProgress(value=0.0, max=725.0), HTML(value='')))
# HBox(children=(HTML(value='Iteration'), FloatProgress(value=0.0, max=725.0), HTML(value='')))
# HBox(children=(HTML(value='Iteration'), FloatProgress(value=0.0, max=725.0), HTML(value='')))
# HBox(children=(HTML(value='Iteration'), FloatProgress(value=0.0, max=725.0), HTML(value='')))
# HBox(children=(HTML(value='Iteration'), FloatProgress(value=0.0, max=725.0), HTML(value='')))
# HBox(children=(HTML(value='Iteration'), FloatProgress(value=0.0, max=725.0), HTML(value='')))
# HBox(children=(HTML(value='Iteration'), FloatProgress(value=0.0, max=725.0), HTML(value='')))
# HBox(children=(HTML(value='Iteration'), FloatProgress(value=0.0, max=725.0), HTML(value='')))
# HBox(children=(HTML(value='Iteration'), FloatProgress(value=0.0, max=725.0), HTML(value='')))
# HBox(children=(HTML(value='Iteration'), FloatProgress(value=0.0, max=725.0), HTML(value='')))
# HBox(children=(HTML(value='Iteration'), FloatProgress(value=0.0, max=725.0), HTML(value='')))
# HBox(children=(HTML(value='Iteration'), FloatProgress(value=0.0, max=725.0), HTML(value='')))
# HBox(children=(HTML(value='Iteration'), FloatProgress(value=0.0, max=725.0), HTML(value='')))

# %%
model.save(sbert_new_model_name)

# %% [markdown]
# ### Play with my own sentences

# %%
# Uncomment the following line to load the existing trained model.
# model = sentence_transformers.SentenceTransformer(sbert_new_model_name)

# %%
query_embedding = model.encode('Windows 8, Positive')
passage_embedding = model.encode("This laptop's design is amazing")

print("Similarity:", sentence_transformers.util.pytorch_cos_sim(query_embedding, passage_embedding))
# Out:
# Similarity: tensor([[0.5820]])

# %% [markdown]
# ## k-NN Search

# %%
# Get the top k matches from k-NN search
top_k = 400

# %% [markdown]
# ### Generate query results file for `trec_eval` evaluation: Laptop

# %%
test_laptop_documents_path = os.path.join('..', 'BM25', 'collection', 'laptop_test.jsonl')
test_laptop_documents_file = jsonlines.open(test_laptop_documents_path)

# %%
test_laptop_documents_id = []
test_laptop_documents = []

for d in test_laptop_documents_file:
    test_laptop_documents_id.append(d['id'])
    test_laptop_documents.append(d['contents'])

# %%
# Obtain embedding vector of test documents
test_laptop_embeddings = model.encode(test_laptop_documents, convert_to_tensor=True)

# %%
test_laptop_queries_path = os.path.join('..', 'BM25', 'test_queries_laptop.txt')
test_laptop_queries = open(test_laptop_queries_path, 'r').readlines()

# %%
test_laptop_result_path = os.path.join('.', 'query_results', sbert_new_model_name, 'top_' + str(top_k))
pathlib.Path(test_laptop_result_path).mkdir(parents=True, exist_ok=True)
test_laptop_result_file = 'query_results_laptop_' + sbert_new_model_name + '.txt'

# %%
# !rm {os.path.join(test_laptop_result_path, test_laptop_result_file)}

for q_num, q in enumerate(test_laptop_queries):
    print("Processing query", q_num, ":", q)
    
    query_embedding = model.encode(q, convert_to_tensor=True)

    cos_scores = sentence_transformers.util.pytorch_cos_sim(query_embedding, test_laptop_embeddings)[0]

    if len(cos_scores) < top_k:
        top_k_retrieved = len(cos_scores)
    else:
        top_k_retrieved = top_k

    # We use torch.topk to find the highest 5 scores
    top_results = torch.topk(cos_scores, k=top_k_retrieved)

    # print("\n\n======================\n\n")
    # print("Query:", q)
    # print("\nTop 5 most similar sentences in corpus:")

    # for score, idx in zip(top_results[0], top_results[1]):
    #     print(test_laptop_documents[idx], "(Score: %.4f)" % (score))

    # trec_eval query results file
    i = 0

    for score, idx in zip(top_results[0], top_results[1]):
        line = str(q_num+1) + ' Q0 ' + test_laptop_documents_id[idx] + ' ' + str(i+1) + ' ' + '%.8f' % score + ' galago'

        i = i + 1
      
        with open(os.path.join(test_laptop_result_path, test_laptop_result_file), 'a') as f:
            f.write("%s\n" % line)
# Out:
# rm: cannot remove './Siamese_results/sbert_bert_ada_joint_online_contrastive/top_1000/query_results_laptop_sbert_bert_ada_joint_online_contrastive.txt': No such file or directory
# Processing query 0 : touch pad, positive
#
# Processing query 1 : Windows 8, negative
#
# Processing query 2 : aluminum casing, positive
#
# Processing query 3 : aesthetics, positive
#
# Processing query 4 : software, positive
#
# Processing query 5 : Firewire 800, positive
#
# Processing query 6 : Legacy programs, neutral
#
# Processing query 7 : Price, negative
#
# Processing query 8 : OpenOffice, positive
#
# Processing query 9 : touchscreen functions, negative
#
# Processing query 10 : "tools" menu, neutral
#
# Processing query 11 : itune, negative
#
# Processing query 12 : create your own bookmarks, positive
#
# Processing query 13 : sound quality, negative
#
# Processing query 14 : downloading apps, positive
#
# Processing query 15 : retina display, neutral
#
# Processing query 16 : Samsung 830 SSD, positive
#
# Processing query 17 : windows 8, positive
#
# Processing query 18 : gaming, positive
#
# Processing query 19 : Boot-up, negative
#
# Processing query 20 : 3D rendering, negative
#
# Processing query 21 : USB ports, positive
#
# Processing query 22 : aluminum, negative
#
# Processing query 23 : HDD, positive
#
# Processing query 24 : hard drive, positive
#
# Processing query 25 : body, positive
#
# Processing query 26 : practicality, positive
#
# Processing query 27 : extender cable, neutral
#
# Processing query 28 : touchpad, negative
#
# Processing query 29 : performance, positive
#
# Processing query 30 : disk drive, positive
#
# Processing query 31 : design, neutral
#
# Processing query 32 : compact computing, positive
#
# Processing query 33 : performed, positive
#
# Processing query 34 : Mother Board, negative
#
# Processing query 35 : Screen, positive
#
# Processing query 36 : IOS system, positive
#
# Processing query 37 : power adaptor, neutral
#
# Processing query 38 : Works, positive
#
# Processing query 39 : logic board, negative
#
# Processing query 40 : Quality, positive
#
# Processing query 41 : SDXC slot, negative
#
# Processing query 42 : operating system, positive
#
# Processing query 43 : capabilities, positive
#
# Processing query 44 : install software, negative
#
# Processing query 45 : transport, positive
#
# Processing query 46 : loading the internet, positive
#
# Processing query 47 : USB3, negative
#
# Processing query 48 : updates, neutral
#
# Processing query 49 : backlit keys, negative
#
# Processing query 50 : applications, neutral
#
# Processing query 51 : SD card reader, negative
#
# Processing query 52 : service, positive
#
# Processing query 53 : exterior, positive
#
# Processing query 54 : external microphones, neutral
#
# Processing query 55 : lid, neutral
#
# Processing query 56 : specs, neutral
#
# Processing query 57 : Mac OS, negative
#
# Processing query 58 : quality, positive
#
# Processing query 59 : set up, positive
#
# Processing query 60 : material, negative
#
# Processing query 61 : OSX, negative
#
# Processing query 62 : track pad, negative
#
# Processing query 63 : Cd Rom, neutral
#
# Processing query 64 : external power supply, neutral
#
# Processing query 65 : customize setting, positive
#
# Processing query 66 : power down, negative
#
# Processing query 67 : Win8, negative
#
# Processing query 68 : CD/DVD player, positive
#
# Processing query 69 : install Mountain Lion, negative
#
# Processing query 70 : SSD drive, neutral
#
# Processing query 71 : carry, positive
#
# Processing query 72 : storage, neutral
#
# Processing query 73 : cost, neutral
#
# Processing query 74 : disc drive, neutral
#
# Processing query 75 : word processing, neutral
#
# Processing query 76 : shortcuts, neutral
#
# Processing query 77 : Shipped, positive
#
# Processing query 78 : 4G of RAM, neutral
#
# Processing query 79 : working, positive
#
# Processing query 80 : Windows 8, neutral
#
# Processing query 81 : Fan, neutral
#
# Processing query 82 : adjustments, positive
#
# Processing query 83 : RAM, positive
#
# Processing query 84 : installation disk (DVD), neutral
#
# Processing query 85 : boots up, positive
#
# Processing query 86 : MAC OS, positive
#
# Processing query 87 : log on, positive
#
# Processing query 88 : built-in mic, neutral
#
# Processing query 89 : ssd drive, positive
#
# Processing query 90 : mother boards, neutral
#
# Processing query 91 : disk drive, neutral
#
# Processing query 92 : keyboard, negative
#
# Processing query 93 : Mac OS, positive
#
# Processing query 94 : technical support, neutral
#
# Processing query 95 : DVD drive Firewire port, neutral
#
# Processing query 96 : apps, positive
#
# Processing query 97 : setup, positive
#
# Processing query 98 : SD card slot, neutral
#
# Processing query 99 : Logic board, positive
#
# Processing query 100 : case, neutral
#
# Processing query 101 : "WLAN" card, neutral
#
# Processing query 102 : colors, positive
#
# Processing query 103 : OWC upgrade kit, neutral
#
# Processing query 104 : wireless keyboard / mouse, neutral
#
# Processing query 105 : time response, positive
#
# Processing query 106 : UX, positive
#
# Processing query 107 : restore disks, negative
#
# Processing query 108 : usb ports, negative
#
# Processing query 109 : wireless mouse, neutral
#
# Processing query 110 : programming, neutral
#
# Processing query 111 : priced, positive
#
# Processing query 112 : gestures, positive
#
# Processing query 113 : Bluetooth interface, negative
#
# Processing query 114 : feels, positive
#
# Processing query 115 : external 24" LCD screen, neutral
#
# Processing query 116 : configure, positive
#
# Processing query 117 : tech support, negative
#
# Processing query 118 : durability, positive
#
# Processing query 119 : on/off switch, negative
#
# Processing query 120 : entertainment uses, positive
#
# Processing query 121 : internet, positive
#
# Processing query 122 : technical support, negative
#
# Processing query 123 : volume, negative
#
# Processing query 124 : install, positive
#
# Processing query 125 : profile, negative
#
# Processing query 126 : nail slot on the card, negative
#
# Processing query 127 : Windows 7, positive
#
# Processing query 128 : HDMI cable, neutral
#
# Processing query 129 : keyboard, positive
#
# Processing query 130 : configure for ADSl cable or wifi, positive
#
# Processing query 131 : price tag, positive
#
# Processing query 132 : shipping, negative
#
# Processing query 133 : os, positive
#
# Processing query 134 : flexibility for connectivity, positive
#
# Processing query 135 : portability, positive
#
# Processing query 136 : AppleCare, negative
#
# Processing query 137 : iPhoto, positive
#
# Processing query 138 : case, negative
#
# Processing query 139 : brightness, positive
#
# Processing query 140 : network lights, neutral
#
# Processing query 141 : fonts, negative
#
# Processing query 142 : ventilation system, negative
#
# Processing query 143 : range, negative
#
# Processing query 144 : Windows 7, neutral
#
# Processing query 145 : looking, positive
#
# Processing query 146 : surfing, positive
#
# Processing query 147 : screen display, positive
#
# Processing query 148 : tutorial, neutral
#
# Processing query 149 : delivery, positive
#
# Processing query 150 : Acer support, neutral
#
# Processing query 151 : built in screen size, neutral
#
# Processing query 152 : sound, negative
#
# Processing query 153 : operating system files, neutral
#
# Processing query 154 : settings, negative
#
# Processing query 155 : Safari browser, positive
#
# Processing query 156 : price, negative
#
# Processing query 157 : USB3, positive
#
# Processing query 158 : look, positive
#
# Processing query 159 : word processing program, neutral
#
# Processing query 160 : Runs, positive
#
# Processing query 161 : third-generation CPU ("Ivy Bridge"), neutral
#
# Processing query 162 : pad, negative
#
# Processing query 163 : SuperDrive, positive
#
# Processing query 164 : built in features, positive
#
# Processing query 165 : wakes, positive
#
# Processing query 166 : rubber pads, negative
#
# Processing query 167 : storage, positive
#
# Processing query 168 : touch, positive
#
# Processing query 169 : iDVD, negative
#
# Processing query 170 : startup disk, neutral
#
# Processing query 171 : finger swipes, negative
#
# Processing query 172 : components, negative
#
# Processing query 173 : keys, neutral
#
# Processing query 174 : heat output, positive
#
# Processing query 175 : res, positive
#
# Processing query 176 : Startup times, negative
#
# Processing query 177 : value, positive
#
# Processing query 178 : System, positive
#
# Processing query 179 : size, neutral
#
# Processing query 180 : Microsoft Windows, neutral
#
# Processing query 181 : Microphone jack, neutral
#
# Processing query 182 : MagSafe accessories, neutral
# Processing query 183 : screen, neutral
#
# Processing query 184 : CUSTOMER SERVICE, positive
#
# Processing query 185 : hardware (keyboard), negative
#
# Processing query 186 : mountain lion, negative
#
# Processing query 187 : track pad, positive
#
# Processing query 188 : performance, negative
#
# Processing query 189 : customer service, positive
#
# Processing query 190 : performs, positive
#
# Processing query 191 : click pads, negative
#
# Processing query 192 : games, neutral
#
# Processing query 193 : remove the card, negative
#
# Processing query 194 : Office, neutral
#
# Processing query 195 : integrate bluetooth devices, positive
#
# Processing query 196 : Microsoft Word, neutral
#
# Processing query 197 : os.x, neutral
#
# Processing query 198 : battery cycle count, positive
#
# Processing query 199 : FireWire 800, neutral
#
# Processing query 200 : battery life, positive
#
# Processing query 201 : headphones, neutral
#
# Processing query 202 : built-in camera, neutral
#
# Processing query 203 : Starts up, positive
#
# Processing query 204 : Mountain Lion OS, positive
#
# Processing query 205 : Mavericks, positive
#
# Processing query 206 : graphic design, positive
#
# Processing query 207 : OSX Lion, positive
#
# Processing query 208 : Appleworks, neutral
#
# Processing query 209 : cover, neutral
#
# Processing query 210 : Gigabit Ethernet, neutral
#
# Processing query 211 : price tag, neutral
#
# Processing query 212 : i5 processor, positive
#
# Processing query 213 : softwares, neutral
#
# Processing query 214 : Screen resolution, negative
#
# Processing query 215 : functions provided by the trackpad, positive
#
# Processing query 216 : bass, negative
#
# Processing query 217 : XP, neutral
#
# Processing query 218 : integrated Intel 4000 card, neutral
#
# Processing query 219 : Mavericks, neutral
#
# Processing query 220 : right mouse click menu, neutral
#
# Processing query 221 : OS, positive
#
# Processing query 222 : designed, positive
#
# Processing query 223 : MagSafe 2 connection, negative
#
# Processing query 224 : form factor, positive
#
# Processing query 225 : monitors, neutral
#
# Processing query 226 : windows 7, positive
#
# Processing query 227 : retina display display, positive
#
# Processing query 228 : resolution, positive
#
# Processing query 229 : Windows 7, negative
#
# Processing query 230 : HDMI cables, neutral
#
# Processing query 231 : built in virus control, positive
#
# Processing query 232 : function, positive
#
# Processing query 233 : multi touch gestures, positive
#
# Processing query 234 : features, neutral
#
# Processing query 235 : functionality, positive
#
# Processing query 236 : graphic design, neutral
#
# Processing query 237 : spec, negative
#
# Processing query 238 : weight, positive
#
# Processing query 239 : hardware, negative
#
# Processing query 240 : Quicken, neutral
#
# Processing query 241 : design app, neutral
#
# Processing query 242 : FileMaker Pro, neutral
#
# Processing query 243 : graphics stuff, positive
#
# Processing query 244 : Boot time, positive
#
# Processing query 245 : memory, neutral
#
# Processing query 246 : Seagate Momentus XT hybrid drives, neutral
#
# Processing query 247 : hardware, positive
#
# Processing query 248 : price, neutral
#
# Processing query 249 : playing steam games, neutral
#
# Processing query 250 : USB 2 ports, neutral
#
# Processing query 251 : Microsoft Office, positive
#
# Processing query 252 : watching videos, neutral
#
# Processing query 253 : built quality, positive
#
# Processing query 254 : durability of the battery, positive
#
# Processing query 255 : gaming, neutral
#
# Processing query 256 : 8G of RAM, neutral
#
# Processing query 257 : regular hard drive, positive
#
# Processing query 258 : HDMI receptacle, neutral
#
# Processing query 259 : settings, neutral
#
# Processing query 260 : Mini form factor, positive
#
# Processing query 261 : Apple "Help", negative
#
# Processing query 262 : footprint, positive
#
# Processing query 263 : Build Quality, positive
#
# Processing query 264 : audio volume, negative
#
# Processing query 265 : Windows, negative
#
# Processing query 266 : lighted screen, positive
#
# Processing query 267 : instructions, negative
#
# Processing query 268 : display, positive
#
# Processing query 269 : Cost, negative
#
# Processing query 270 : i5, negative
#
# Processing query 271 : windows Vista, neutral
#
# Processing query 272 : Windows 8, positive
#
# Processing query 273 : simplicity, positive
#
# Processing query 274 : right click button, neutral
#
# Processing query 275 : Mac ecosystem, neutral
#
# Processing query 276 : starts up, positive
#
# Processing query 277 : external mics, neutral
#
# Processing query 278 : operation, negative
#
# Processing query 279 : Quad-Core 2.5 GHz CPU, neutral
#
# Processing query 280 : security, positive
#
# Processing query 281 : anodized aluminum, positive
#
# Processing query 282 : Apple Customer Support, neutral
#
# Processing query 283 : boot, neutral
#
# Processing query 284 : playing a game, neutral
#
# Processing query 285 : Set up, positive
#
# Processing query 286 : media editing, positive
#
# Processing query 287 : "Home/End" type keys, neutral
#
# Processing query 288 : shipment, positive
#
# Processing query 289 : CD/DVD drive, neutral
#
# Processing query 290 : warranty, positive
#
# Processing query 291 : word processing, positive
#
# Processing query 292 : garage band, neutral
#
# Processing query 293 : gaming, negative
#
# Processing query 294 : memory, positive
#
# Processing query 295 : RAM memory, positive
#
# Processing query 296 : power switch, negative
#
# Processing query 297 : internal speakers, negative
#
# Processing query 298 : photoshop, neutral
#
# Processing query 299 : ethernet, neutral
#
# Processing query 300 : snow lion, positive
#
# Processing query 301 : handle, positive
#
# Processing query 302 : voice recording, negative
#
# Processing query 303 : Customization, negative
#
# Processing query 304 : cable, positive
#
# Processing query 305 : package, positive
#
# Processing query 306 : Mac OS 10.9, negative
#
# Processing query 307 : word program, negative
#
# Processing query 308 : fans, positive
#
# Processing query 309 : screen, positive
#
# Processing query 310 : touch screen, neutral
#
# Processing query 311 : work, negative
#
# Processing query 312 : start up, positive
#
# Processing query 313 : looks, positive
#
# Processing query 314 : battery lifetime, negative
#
# Processing query 315 : Windows updates, negative
#
# Processing query 316 : adapter, neutral
#
# Processing query 317 : Mac OS X 10.8 "Mountain Lion", neutral
#
# Processing query 318 : system, negative
#
# Processing query 319 : ThunderBolt, negative
#
# Processing query 320 : web browsing, neutral
#
# Processing query 321 : CD slot, neutral
#
# Processing query 322 : works, positive
#
# Processing query 323 : packing, positive
#
# Processing query 324 : speakers, negative
#
# Processing query 325 : Harddrive, negative
#
# Processing query 326 : two finger clicking, positive
#
# Processing query 327 : slot, negative
#
# Processing query 328 : LAN device drivers, neutral
#
# Processing query 329 : key board, neutral
#
# Processing query 330 : Performance, positive
#
# Processing query 331 : finish, positive
#
# Processing query 332 : sound, positive
#
# Processing query 333 : interneting, negative
#
# Processing query 334 : product quality, positive
#
# Processing query 335 : trackpad, positive
#
# Processing query 336 : system, neutral
#
# Processing query 337 : battery, neutral
#
# Processing query 338 : 16GB of RAM, neutral
#
# Processing query 339 : ports, positive
#
# Processing query 340 : Lion, positive
#
# Processing query 341 : Mac system, negative
#
# Processing query 342 : cost of ownership, neutral
#
# Processing query 343 : speaker quality, negative
#
# Processing query 344 : build, positive
#
# Processing query 345 : navigate, positive
#
# Processing query 346 : SSD, neutral
#
# Processing query 347 : Photoshop, neutral
#
# Processing query 348 : lit up keys, positive
#
# Processing query 349 : photo editing, positive
#
# Processing query 350 : priced, neutral
#
# Processing query 351 : iPhoto, neutral
#
# Processing query 352 : Radeon HD 6750M 512MB graphic card, neutral
#
# Processing query 353 : features, negative
#
# Processing query 354 : SquareTrade 3-Year Computer Accidental Protection Warranty, positive
#
# Processing query 355 : features, positive
#
# Processing query 356 : power plug, negative
#
# Processing query 357 : scanning, negative
#
# Processing query 358 : ports, neutral
#
# Processing query 359 : recovery USB stick, neutral
#
# Processing query 360 : log into the system, negative
#
# Processing query 361 : baterry, positive
#
# Processing query 362 : interface, positive
# Processing query 363 : built, positive
#
# Processing query 364 : OS, negative
#
# Processing query 365 : TRACKPAD, negative
#
# Processing query 366 : intel 4000 graphics chipset, neutral
#
# Processing query 367 : glass, positive
#
# Processing query 368 : construction, positive
#
# Processing query 369 : mouse, neutral
#
# Processing query 370 : USB3 Peripherals, positive
#
# Processing query 371 : slim plastic case, neutral
#
# Processing query 372 : aluminum, positive
#
# Processing query 373 : apple OS, positive
#
# Processing query 374 : card reader, negative
#
# Processing query 375 : software, neutral
#
# Processing query 376 : windows, positive
#
# Processing query 377 : Micron SSD, neutral
#
# Processing query 378 : built-in applications, positive
#
# Processing query 379 : number pad on the keyboard, positive
#
# Processing query 380 : windows, neutral
#
# Processing query 381 : CD/DVD player, neutral
#
# Processing query 382 : Shipping, positive
#
# Processing query 383 : delete key, negative
#
# Processing query 384 : OSX Mountain Lion, neutral
#
# Processing query 385 : USB ports, neutral
#
# Processing query 386 : mouse, positive
#
# Processing query 387 : video, positive
#
# Processing query 388 : internal CD drive, negative
#
# Processing query 389 : DVD slot, neutral
#
# Processing query 390 : virtual home schooling, positive
#
# Processing query 391 : portable computing, positive
#
# Processing query 392 : SSD, positive
#
# Processing query 393 : Windows 8 Set-Up, negative
#
# Processing query 394 : iTunes, positive
#
# Processing query 395 : Web surfuring, positive
#
# Processing query 396 : Hardware performance, positive
#
# Processing query 397 : craftmanship, positive
#
# Processing query 398 : charging cables, negative
#
# Processing query 399 : Intel4000 graphic chip, negative
#
# Processing query 400 : windows XP, neutral
#
# Processing query 401 : Audio, positive
#
# Processing query 402 : operation, positive
#
# Processing query 403 : MagSafe port, neutral
#
# Processing query 404 : VGA port, neutral
#
# Processing query 405 : OS X Mountain Lion, neutral
#
# Processing query 406 : physical form, positive
#
# Processing query 407 : MAC OS, negative
#
# Processing query 408 : graphics card, negative
#
# Processing query 409 : WiFi connection, positive
#
# Processing query 410 : mobility, positive
#
# Processing query 411 : appearance, positive
#
# Processing query 412 : HDMI port, neutral
#
# Processing query 413 : aluminum body, positive
#
# Processing query 414 : fourth-generation Haswell CPU, neutral
#
# Processing query 415 : windows 8, negative
#
# Processing query 416 : overall build, positive
#
# Processing query 417 : battery, negative
#
# Processing query 418 : price point, neutral
#
# Processing query 419 : RAM, negative
#
# Processing query 420 : start menu, neutral
#
# Processing query 421 : Built-in apps, positive
#
# Processing query 422 : use, positive
#
# Processing query 423 : firmware patch, neutral
#
# Processing query 424 : memory, negative
#
# Processing query 425 : MS Office 2011 for Mac, positive
#
# Processing query 426 : runs, positive
#
# Processing query 427 : spinning hard disk, neutral
#
# Processing query 428 : thunderbolt port, positive
#
# Processing query 429 : HDMI, neutral
#
# Processing query 430 : support for games, negative
#
# Processing query 431 : usability, positive
#
# Processing query 432 : design, positive
#
# Processing query 433 : wireless Apple Keyboard and Mouse, neutral
#
# Processing query 434 : Mac tutorials, positive
#
# Processing query 435 : hard drive, neutral
#
# Processing query 436 : shipping, positive
#
# Processing query 437 : USB3, neutral
#
# Processing query 438 : battery, positive
#
# Processing query 439 : 2.9ghz dual-core i7 chip, positive
#
# Processing query 440 : 16Gb RAM, neutral
#
# Processing query 441 : Mac office, negative
#
# Processing query 442 : price, positive
#
# Processing query 443 : USB devices, positive
#
# Processing query 444 : support, negative
#
# Processing query 445 : specs, positive
#
# Processing query 446 : WiFi capability, positive
#
# Processing query 447 : upgrade the ram, positive
#
# Processing query 448 : user experience, positive
#
# Processing query 449 : size, positive
#
# Processing query 450 : application, negative
#
# Processing query 451 : speed, positive
#
# Processing query 452 : Keyboard, positive
#
# Processing query 453 : configuration, positive
#
# Processing query 454 : HD, neutral
#
# Processing query 455 : graphics, positive
#
# Processing query 456 : presentation, positive
#
# Processing query 457 : AC adaptor, neutral
#
# Processing query 458 : flexibility, positive
#
# Processing query 459 : application, positive
#
# Processing query 460 : brightness, neutral
#
# Processing query 461 : USB ports, negative
#
# Processing query 462 : start up, negative
#
# Processing query 463 : Graphics, positive
#
# Processing query 464 : aluminium, positive
#
# Processing query 465 : Apple Tech Support, neutral
#
# Processing query 466 : function, negative
#
# Processing query 467 : OS, neutral
#
# Processing query 468 : content creation, positive
#
# Processing query 469 : 21" LED screen, neutral
#
# Processing query 470 : performance, neutral
#
# Processing query 471 : streaming video, positive
#
# Processing query 472 : performance and feature set of the hardware, neutral
#
# Processing query 473 : Web browsing, positive
#
# Processing query 474 : unibody construction, positive

# %% [markdown]
# ### Generate query results file for `trec_eval` evaluation: Restaurant

# %%
test_restaurants_documents_path = os.path.join('..', 'BM25', 'collection', 'restaurant_test.jsonl')
test_restaurants_documents_file = jsonlines.open(test_restaurants_documents_path)

# %%
test_restaurants_documents_id = []
test_restaurants_documents = []

for d in test_restaurants_documents_file:
    test_restaurants_documents_id.append(d['id'])
    test_restaurants_documents.append(d['contents'])

test_restaurants_embeddings = model.encode(test_restaurants_documents, convert_to_tensor=True)

# %%
test_restaurants_queries_path = os.path.join('..', 'BM25', 'test_queries_restaurant.txt')
test_restaurants_queries = open(test_restaurants_queries_path, 'r').readlines()

# %%
test_restaurants_result_path = os.path.join('.', 'query_results', sbert_new_model_name, 'top_' + str(top_k))
pathlib.Path(test_restaurants_result_path).mkdir(parents=True, exist_ok=True)
test_restaurants_result_file = 'query_results_restaurants_' + sbert_new_model_name + '.txt'

# %%
# !rm {os.path.join(test_restaurants_result_path, test_restaurants_result_file)}

for q_num, q in enumerate(test_restaurants_queries):
    print("Processing query", q_num, ":", q)

    query_embedding = model.encode(q, convert_to_tensor=True)

    cos_scores = sentence_transformers.util.pytorch_cos_sim(query_embedding, test_restaurants_embeddings)[0]

    if len(cos_scores) < top_k:
        top_k_retrieved = len(cos_scores)
    else:
        top_k_retrieved = top_k

    # We use torch.topk to find the highest 5 scores
    top_results = torch.topk(cos_scores, k=top_k_retrieved)

    # print("\n\n======================\n\n")
    # print("Query:", q)
    # print("\nTop 5 most similar sentences in corpus:")

    # for score, idx in zip(top_results[0], top_results[1]):
    #     print(test_laptop_documents[idx], "(Score: %.4f)" % (score))

    # trec_eval query results file
    i = 0

    for score, idx in zip(top_results[0], top_results[1]):
        line = str(q_num+1) + ' Q0 ' + test_restaurants_documents_id[idx] + ' ' + str(i+1) + ' ' + '%.8f' % score + ' galago'

        i = i + 1
      
        with open(os.path.join(test_restaurants_result_path, test_restaurants_result_file), 'a') as f:
            f.write("%s\n" % line)
# Out:
# rm: cannot remove './Siamese_results/sbert_bert_ada_joint_online_contrastive/top_1000/query_results_restaurants_sbert_bert_ada_joint_online_contrastive.txt': No such file or directory
# Processing query 0 : chicken and falafel platters, neutral
#
# Processing query 1 : Appetizer, positive
#
# Processing query 2 : waiters, negative
#
# Processing query 3 : taglierini with truffles, positive
#
# Processing query 4 : chicken, negative
#
# Processing query 5 : caviar-topped sturgeon, positive
#
# Processing query 6 : beers, neutral
#
# Processing query 7 : tabouleh, positive
#
# Processing query 8 : cajun shrimp, neutral
#
# Processing query 9 : brisket, positive
#
# Processing query 10 : dumplings, positive
#
# Processing query 11 : sweet corn-foie gras brulee, neutral
#
# Processing query 12 : garlic knots, positive
#
# Processing query 13 : reservations, neutral
#
# Processing query 14 : quality of the meat, negative
#
# Processing query 15 : taste, negative
#
# Processing query 16 : Service, negative
#
# Processing query 17 : brunch, neutral
#
# Processing query 18 : argentine chorizo appetizer, negative
#
# Processing query 19 : new menu, positive
#
# Processing query 20 : seafood, positive
#
# Processing query 21 : Foie Gras Unagi Napolean, neutral
#
# Processing query 22 : WAITERS, neutral
#
# Processing query 23 : steaks, negative
#
# Processing query 24 : lunch, positive
#
# Processing query 25 : hostess, positive
#
# Processing query 26 : hint of cocoa, positive
#
# Processing query 27 : new hamburger with special sauce, positive
#
# Processing query 28 : AC, negative
#
# Processing query 29 : traditional Italian items, positive
#
# Processing query 30 : flan, neutral
#
# Processing query 31 : beer, positive
#
# Processing query 32 : deserts, positive
#
# Processing query 33 : Big Mac, positive
#
# Processing query 34 : Owner, positive
#
# Processing query 35 : rose roll, positive
#
# Processing query 36 : honey BBQ rib tips, positive
#
# Processing query 37 : middle eastern spreads, positive
#
# Processing query 38 : dessert, neutral
#
# Processing query 39 : delivery service, positive
#
# Processing query 40 : Calf's liver, positive
#
# Processing query 41 : chocolate and peanut butter tart, positive
#
# Processing query 42 : lounge, neutral
#
# Processing query 43 : kitchen food, positive
#
# Processing query 44 : crust, negative
#
# Processing query 45 : priced, negative
#
# Processing query 46 : meals, neutral
#
# Processing query 47 : Delmonico steak, negative
#
# Processing query 48 : appetizers, positive
#
# Processing query 49 : lunch, neutral
#
# Processing query 50 : sangria, negative
#
# Processing query 51 : appetizer, neutral
#
# Processing query 52 : vegetarian platters, positive
#
# Processing query 53 : desserts, neutral
#
# Processing query 54 : scenery, negative
#
# Processing query 55 : dinners, negative
#
# Processing query 56 : McDonald's famous french fries, positive
#
# Processing query 57 : meal, negative
#
# Processing query 58 : counter, neutral
#
# Processing query 59 : lighting, negative
#
# Processing query 60 : iced blended mocha, positive
#
# Processing query 61 : wine list, negative
#
# Processing query 62 : utensils, neutral
#
# Processing query 63 : "Roy's Classics", positive
#
# Processing query 64 : bar menu, negative
#
# Processing query 65 : portions of the food, neutral
#
# Processing query 66 : appetizer selection, negative
#
# Processing query 67 : service, positive
#
# Processing query 68 : asian fusion, neutral
#
# Processing query 69 : cocktail menu, positive
#
# Processing query 70 : look, negative
#
# Processing query 71 : drinks, negative
#
# Processing query 72 : halibut cheek appetizer, neutral
#
# Processing query 73 : dance floor, neutral
#
# Processing query 74 : delivers, positive
#
# Processing query 75 : quality, positive
#
# Processing query 76 : LASAGNA, positive
#
# Processing query 77 : sashimi, negative
#
# Processing query 78 : tacos, positive
#
# Processing query 79 : Tostada de Tinga, positive
#
# Processing query 80 : ice drink, positive
#
# Processing query 81 : dinner, neutral
#
# Processing query 82 : starter, neutral
#
# Processing query 83 : Korean dishes, positive
#
# Processing query 84 : wheat crusted pizza, positive
#
# Processing query 85 : Cinna Stix, neutral
#
# Processing query 86 : curry, positive
#
# Processing query 87 : Tequila, positive
#
# Processing query 88 : fresh leaf salad, neutral
#
# Processing query 89 : people, negative
#
# Processing query 90 : dabs of real mozzarella, neutral
#
# Processing query 91 : salmon dishes, positive
#
# Processing query 92 : menu, neutral
#
# Processing query 93 : waitresses, positive
#
# Processing query 94 : assortment of wraps, positive
#
# Processing query 95 : soy mayonaise, positive
#
# Processing query 96 : MAC AND CHEESE, negative
#
# Processing query 97 : pasta, positive
#
# Processing query 98 : steaks, neutral
#
# Processing query 99 : Host, negative
#
# Processing query 100 : pizza, positive
#
# Processing query 101 : caeser salad, positive
#
# Processing query 102 : humus, positive
#
# Processing query 103 : port, positive
#
# Processing query 104 : slices, negative
#
# Processing query 105 : table, neutral
#
# Processing query 106 : bartenders, negative
#
# Processing query 107 : french fries -- with the kalmata dip, positive
#
# Processing query 108 : appetizer, positive
#
# Processing query 109 : Nicoise salad, negative
#
# Processing query 110 : pasta specials, positive
#
# Processing query 111 : green beans, neutral
#
# Processing query 112 : falafal, negative
#
# Processing query 113 : manager, negative
#
# Processing query 114 : wine, neutral
#
# Processing query 115 : parmesan cheese, neutral
#
# Processing query 116 : erbazzone emiliana, positive
#
# Processing query 117 : kitchen, neutral
#
# Processing query 118 : priced, positive
#
# Processing query 119 : fish, positive
#
# Processing query 120 : Atmosphere, negative
#
# Processing query 121 : asian salad, positive
#
# Processing query 122 : fries, neutral
#
# Processing query 123 : salads (avocado shrimp), positive
#
# Processing query 124 : burger, neutral
#
# Processing query 125 : booth by the windows, neutral
#
# Processing query 126 : attitude, positive
#
# Processing query 127 : orange donut, neutral
#
# Processing query 128 : Desserts, positive
#
# Processing query 129 : take-out, neutral
#
# Processing query 130 : drink, neutral
#
# Processing query 131 : red onion, neutral
#
# Processing query 132 : dishes, positive
#
# Processing query 133 : veggie burger, positive
#
# Processing query 134 : orange chicken/beef, positive
#
# Processing query 135 : music, positive
#
# Processing query 136 : fajita, negative
#
# Processing query 137 : hot dogs, positive
#
# Processing query 138 : Management, negative
#
# Processing query 139 : flavors, neutral
#
# Processing query 140 : teriyaki, positive
#
# Processing query 141 : spinach thing, positive
#
# Processing query 142 : vegetable risotto, negative
#
# Processing query 143 : blue bar area, positive
#
# Processing query 144 : shrimp dishs, positive
#
# Processing query 145 : sushi, neutral
#
# Processing query 146 : lychee martini, positive
#
# Processing query 147 : Menus, neutral
#
# Processing query 148 : soup and sandwich meal, positive
#
# Processing query 149 : dessert pizza, neutral
#
# Processing query 150 : Deco, positive
#
# Processing query 151 : pastas, positive
#
# Processing query 152 : location, negative
#
# Processing query 153 : lunch, negative
#
# Processing query 154 : Greek food, positive
#
# Processing query 155 : hong kong-style food, positive
#
# Processing query 156 : waitstaff, positive
#
# Processing query 157 : chairs, positive
#
# Processing query 158 : Cherry Marscapone, neutral
#
# Processing query 159 : afternoon snack, positive
#
# Processing query 160 : soft shell crab, neutral
#
# Processing query 161 : warm pitas, neutral
#
# Processing query 162 : staff members, positive
#
# Processing query 163 : wait, negative
#
# Processing query 164 : kimono shrimp special, positive
#
# Processing query 165 : root vegetables, positive
#
# Processing query 166 : place, neutral
#
# Processing query 167 : folding chair, negative
#
# Processing query 168 : falafel, positive
#
# Processing query 169 : delivery, positive
#
# Processing query 170 : waitress's, negative
#
# Processing query 171 : dish, positive
#
# Processing query 172 : Dishes, positive
#
# Processing query 173 : Dessert, positive
#
# Processing query 174 : Italian cuisine, positive
#
# Processing query 175 : chicken tacos, positive
#
# Processing query 176 : vibe, positive
#
# Processing query 177 : price, negative
#
# Processing query 178 : garlic soup, positive
#
# Processing query 179 : mojito, positive
# Processing query 180 : hostess, negative
#
# Processing query 181 : [female] servers, positive
#
# Processing query 182 : courses, neutral
#
# Processing query 183 : lobster ravioli, positive
#
# Processing query 184 : hot cakes, neutral
#
# Processing query 185 : sushi, negative
#
# Processing query 186 : outdoors, positive
#
# Processing query 187 : Chef, positive
#
# Processing query 188 : waiters, positive
#
# Processing query 189 : Jap style hamburger steak, neutral
#
# Processing query 190 : bi-level space, positive
#
# Processing query 191 : lamb kebabs, positive
#
# Processing query 192 : music, neutral
#
# Processing query 193 : waiter, negative
#
# Processing query 194 : creme brulee, positive
#
# Processing query 195 : portobello/gorgonzola/sausage appetizer, positive
#
# Processing query 196 : latin food, positive
#
# Processing query 197 : steak, positive
#
# Processing query 198 : rice, positive
#
# Processing query 199 : value, positive
#
# Processing query 200 : hot white mocha, positive
#
# Processing query 201 : Meal, negative
#
# Processing query 202 : big mac, negative
#
# Processing query 203 : vegetables, positive
#
# Processing query 204 : kompot, positive
#
# Processing query 205 : cake, positive
#
# Processing query 206 : waiter, positive
#
# Processing query 207 : artifical lobster meat, negative
#
# Processing query 208 : sushi, positive
#
# Processing query 209 : manager, neutral
#
# Processing query 210 : foie gras, positive
#
# Processing query 211 : bartender, neutral
#
# Processing query 212 : sweets, positive
#
# Processing query 213 : host, positive
#
# Processing query 214 : non-sushi selection, positive
#
# Processing query 215 : pialla, positive
#
# Processing query 216 : fettucino alfredo, positive
#
# Processing query 217 : variety, positive
#
# Processing query 218 : staff memebers, positive
#
# Processing query 219 : Branzini, neutral
#
# Processing query 220 : managers, positive
#
# Processing query 221 : escargot, positive
#
# Processing query 222 : sandwiches, neutral
#
# Processing query 223 : chicken parmigiana, neutral
#
# Processing query 224 : people, positive
#
# Processing query 225 : bartender, positive
#
# Processing query 226 : ribs, positive
#
# Processing query 227 : chicken, positive
#
# Processing query 228 : servers, positive
#
# Processing query 229 : vegan options, positive
#
# Processing query 230 : chicken milanese, positive
#
# Processing query 231 : portion size, positive
#
# Processing query 232 : cocktail hour, positive
#
# Processing query 233 : recipes, positive
#
# Processing query 234 : breakfast food, neutral
#
# Processing query 235 : naan, positive
#
# Processing query 236 : Vietnamese Beef Noodle Soup, neutral
#
# Processing query 237 : mango margareta, positive
#
# Processing query 238 : crust, positive
#
# Processing query 239 : appetizers, neutral
#
# Processing query 240 : round corner table next to the large window, positive
#
# Processing query 241 : twist on pizza, positive
#
# Processing query 242 : waitress, neutral
#
# Processing query 243 : Onion Rings, positive
#
# Processing query 244 : soup, positive
#
# Processing query 245 : reservation, neutral
#
# Processing query 246 : owners, positive
#
# Processing query 247 : prices, positive
#
# Processing query 248 : room, positive
#
# Processing query 249 : toppings, positive
#
# Processing query 250 : hot and sour soup, positive
#
# Processing query 251 : steak, neutral
#
# Processing query 252 : dessert, positive
#
# Processing query 253 : pasta primavera, positive
#
# Processing query 254 : beer selection, positive
#
# Processing query 255 : sweets, neutral
#
# Processing query 256 : homemade pastas, positive
#
# Processing query 257 : Peanut Butter Sorbet, positive
#
# Processing query 258 : cheese plate, neutral
#
# Processing query 259 : Greek yogurt (with cuccumber, dill, and garlic), positive
#
# Processing query 260 : Churrasco, positive
#
# Processing query 261 : disco pop duo, negative
#
# Processing query 262 : back patio, positive
#
# Processing query 263 : coconut rice, positive
#
# Processing query 264 : Desserts, neutral
#
# Processing query 265 : Cuisine, negative
#
# Processing query 266 : owners, negative
#
# Processing query 267 : breakfast, neutral
#
# Processing query 268 : Seafood Paella for two, positive
#
# Processing query 269 : staff person, neutral
#
# Processing query 270 : carrots, positive
#
# Processing query 271 : shepherds pie, neutral
#
# Processing query 272 : chocolate Frosty, positive
#
# Processing query 273 : Yellowfin Tuna, positive
#
# Processing query 274 : Tacos Pastor, positive
#
# Processing query 275 : burgers, positive
#
# Processing query 276 : clientele, positive
#
# Processing query 277 : Tart of the Day, positive
#
# Processing query 278 : staff, negative
#
# Processing query 279 : bar service, negative
#
# Processing query 280 : spicy tuna roll, positive
#
# Processing query 281 : food, positive
#
# Processing query 282 : BANANA PUDDING, negative
#
# Processing query 283 : server, positive
#
# Processing query 284 : dining, neutral
#
# Processing query 285 : Waiters, positive
#
# Processing query 286 : fresh juices, positive
#
# Processing query 287 : chairs, neutral
#
# Processing query 288 : potato spinach gnocchi, positive
#
# Processing query 289 : happy hour, positive
#
# Processing query 290 : roti canai appetizer, positive
#
# Processing query 291 : quality of food, positive
#
# Processing query 292 : french dish, neutral
#
# Processing query 293 : garden, positive
#
# Processing query 294 : portabella lasagna, neutral
#
# Processing query 295 : meaty chili, neutral
#
# Processing query 296 : owner, positive
#
# Processing query 297 : black vinegar, neutral
#
# Processing query 298 : pub fare, neutral
#
# Processing query 299 : live entertainment, positive
#
# Processing query 300 : entree, positive
#
# Processing query 301 : black cod with miso base, neutral
#
# Processing query 302 : Malted Milk Ball Gelato, positive
#
# Processing query 303 : cheese baclava, positive
#
# Processing query 304 : calamari, positive
#
# Processing query 305 : breakfast sandwiches, positive
#
# Processing query 306 : pre-show meal, neutral
#
# Processing query 307 : spicy cod roe spaghetti, neutral
#
# Processing query 308 : mostarda on the cheese plate, positive
#
# Processing query 309 : filet mignon, negative
#
# Processing query 310 : steaks, positive
#
# Processing query 311 : portions, positive
#
# Processing query 312 : desserts, positive
#
# Processing query 313 : Filet-O-Fish sandwich, positive
#
# Processing query 314 : prices, negative
#
# Processing query 315 : space, positive
#
# Processing query 316 : organic grilled burgers, positive
#
# Processing query 317 : sandwiches, positive
#
# Processing query 318 : selection, positive
#
# Processing query 319 : rice, neutral
#
# Processing query 320 : patties, positive
#
# Processing query 321 : chili signed food items, negative
#
# Processing query 322 : fresh veggies, positive
#
# Processing query 323 : treats, positive
#
# Processing query 324 : size, negative
#
# Processing query 325 : space, negative
#
# Processing query 326 : Hostess, negative
#
# Processing query 327 : drinks, neutral
#
# Processing query 328 : delivary, negative
#
# Processing query 329 : dining, negative
#
# Processing query 330 : BBQ rib, positive
#
# Processing query 331 : food, negative
#
# Processing query 332 : array of sushi, positive
#
# Processing query 333 : place, positive
#
# Processing query 334 : shrimp creole, positive
#
# Processing query 335 : host (owner), positive
#
# Processing query 336 : fettuccine Alfredo, neutral
#
# Processing query 337 : cooked food, positive
#
# Processing query 338 : FOOD, negative
#
# Processing query 339 : Rabbit stew, positive
#
# Processing query 340 : candlelight, neutral
#
# Processing query 341 : sauce, neutral
#
# Processing query 342 : flan, positive
#
# Processing query 343 : salad, neutral
#
# Processing query 344 : wings, positive
#
# Processing query 345 : rolls, positive
#
# Processing query 346 : soy sauce, neutral
#
# Processing query 347 : food, neutral
#
# Processing query 348 : mac cheese, positive
#
# Processing query 349 : bathroom, positive
#
# Processing query 350 : spicy mussels, positive
#
# Processing query 351 : green chillis, negative
#
# Processing query 352 : Veal Chops, positive
#
# Processing query 353 : sales people, negative
#
# Processing query 354 : Carinthia cheese ravioli with wild mushrooms, positive
#
# Processing query 355 : cookie, negative
#
# Processing query 356 : mole sauce, negative
#
# Processing query 357 : teas, positive
#
# Processing query 358 : waitress, negative
#
# Processing query 359 : Mediterranean delights, positive
# Processing query 360 : outdoor eating area, positive
#
# Processing query 361 : lasagna, neutral
#
# Processing query 362 : Japanese food, negative
#
# Processing query 363 : tapas, positive
#
# Processing query 364 : scallops, neutral
#
# Processing query 365 : selection of wines (primarily Spanish), positive
#
# Processing query 366 : seats, positive
#
# Processing query 367 : fried rice, positive
#
# Processing query 368 : vegan cranberry pancakes, neutral
#
# Processing query 369 : apple tart, positive
#
# Processing query 370 : wine, positive
#
# Processing query 371 : quaility, positive
#
# Processing query 372 : salads, positive
#
# Processing query 373 : staff, positive
#
# Processing query 374 : cost, negative
#
# Processing query 375 : Tables, negative
#
# Processing query 376 : chinese food, negative
#
# Processing query 377 : black roasted codfish, positive
#
# Processing query 378 : soups, neutral
#
# Processing query 379 : Amazin' Greens salads, neutral
#
# Processing query 380 : mango chicken, positive
#
# Processing query 381 : Creamy appetizers, positive
#
# Processing query 382 : chicken dinner, positive
#
# Processing query 383 : apetizers, positive
#
# Processing query 384 : jazz singer, positive
#
# Processing query 385 : paratha, positive
#
# Processing query 386 : Prices, positive
#
# Processing query 387 : wraps, positive
#
# Processing query 388 : escargot, negative
#
# Processing query 389 : Sashimi portion, positive
#
# Processing query 390 : decoration, positive
#
# Processing query 391 : chick peas with shrimp (appetizer), positive
#
# Processing query 392 : Service, positive
#
# Processing query 393 : portions, negative
#
# Processing query 394 : pizza, neutral
#
# Processing query 395 : dining experience, positive
#
# Processing query 396 : cold sesame noodles, positive
#
# Processing query 397 : meal, neutral
#
# Processing query 398 : fried foods, negative
#
# Processing query 399 : salad dressing, neutral
#
# Processing query 400 : braised lamb shank with mashed potatoes, positive
#
# Processing query 401 : bill, positive
#
# Processing query 402 : atmosphere, positive
#
# Processing query 403 : smoothies, positive
#
# Processing query 404 : Portuguese cheese cart, positive
#
# Processing query 405 : italian food, positive
#
# Processing query 406 : Chinese food, positive
#
# Processing query 407 : dish, negative
#
# Processing query 408 : Staff, positive
#
# Processing query 409 : wait, positive
#
# Processing query 410 : rooftop bar, neutral
#
# Processing query 411 : dine-in, neutral
#
# Processing query 412 : Ribs, positive
#
# Processing query 413 : Rabbit, positive
#
# Processing query 414 : SERVICE, positive
#
# Processing query 415 : catfish, positive
#
# Processing query 416 : lobster risotto, positive
#
# Processing query 417 : glass of wine, neutral
#
# Processing query 418 : curried casseroles, negative
#
# Processing query 419 : roasted chickens, positive
#
# Processing query 420 : specials, positive
#
# Processing query 421 : parking, positive
#
# Processing query 422 : potato gratin, positive
#
# Processing query 423 : wait staff, positive
#
# Processing query 424 : Fresh veggies, positive
#
# Processing query 425 : Food portion, negative
#
# Processing query 426 : Sliced steak entree, positive
#
# Processing query 427 : drinks, positive
#
# Processing query 428 : stuffed baked potatoes, neutral
#
# Processing query 429 : menu, positive
#
# Processing query 430 : takeout, neutral
#
# Processing query 431 : music, negative
#
# Processing query 432 : burgers, neutral
#
# Processing query 433 : traditional Mediterranean fare, neutral
#
# Processing query 434 : shredded ginger, neutral
#
# Processing query 435 : homemade breads, positive
#
# Processing query 436 : grill, positive
#
# Processing query 437 : Indian food, negative
#
# Processing query 438 : pizza with soy cheese, positive
#
# Processing query 439 : noodle dishes, positive
#
# Processing query 440 : chickpeas, positive
#
# Processing query 441 : fried pancake served with pungent curry dipping sauce, positive
#
# Processing query 442 : anchovy dressing, neutral
#
# Processing query 443 : asparagus, neutral
#
# Processing query 444 : cheese, positive
#
# Processing query 445 : crepes, positive
#
# Processing query 446 : entrees, neutral
#
# Processing query 447 : selection of food, positive
#
# Processing query 448 : display and quality of the food, negative
#
# Processing query 449 : bartender, negative
#
# Processing query 450 : rice dishes, positive
#
# Processing query 451 : casual drink, positive
#
# Processing query 452 : tuna, positive
#
# Processing query 453 : sauce, negative
#
# Processing query 454 : choices of sauces, positive
#
# Processing query 455 : bar, neutral
#
# Processing query 456 : Buffalo Chicken Kickers, neutral
#
# Processing query 457 : ingredients, positive
#
# Processing query 458 : prix fixe menu, neutral
#
# Processing query 459 : lamb, positive
#
# Processing query 460 : soul food, positive
#
# Processing query 461 : long bar, positive
#
# Processing query 462 : portion of foie gras, positive
#
# Processing query 463 : chicken with avocado, positive
#
# Processing query 464 : macadamia-crusted mahi mahi, positive
#
# Processing query 465 : sweet honey-mustard beef short ribs, positive
#
# Processing query 466 : fresh salsa, neutral
#
# Processing query 467 : duck confitte, positive
#
# Processing query 468 : beans, neutral
#
# Processing query 469 : Japanese dishes, neutral
#
# Processing query 470 : Lamb Chops, positive
#
# Processing query 471 : duck, positive
#
# Processing query 472 : ambience, positive
#
# Processing query 473 : avocado salad, positive
#
# Processing query 474 : Cosi sandwiches, negative
#
# Processing query 475 : salmon, negative
#
# Processing query 476 : eggs benedict, positive
#
# Processing query 477 : dinner, positive
#
# Processing query 478 : fennel flavored Italian sausage, negative
#
# Processing query 479 : nicoise olives, neutral
#
# Processing query 480 : scene, positive
#
# Processing query 481 : chicken, neutral
#
# Processing query 482 : thin crust, negative
#
# Processing query 483 : served, negative
#
# Processing query 484 : wine list, positive
#
# Processing query 485 : upstrairs dining area, neutral
#
# Processing query 486 : main courses, positive
#
# Processing query 487 : lemon-dressed cobb, positive
#
# Processing query 488 : pork product, positive
#
# Processing query 489 : side orders, neutral
#
# Processing query 490 : boutique selection of wines, neutral
#
# Processing query 491 : tables, negative
#
# Processing query 492 : mushroom barley soup, positive
#
# Processing query 493 : Saketini, positive
#
# Processing query 494 : green spinach-vodka sauce, positive
#
# Processing query 495 : sauce cart, neutral
#
# Processing query 496 : space, neutral
#
# Processing query 497 : dining experience, negative
#
# Processing query 498 : Smoked Trout, positive
#
# Processing query 499 : Garlic Shrimp, neutral
#
# Processing query 500 : fried calamari, positive
#
# Processing query 501 : employees, negative
#
# Processing query 502 : fried pork dumplings, positive
#
# Processing query 503 : entree-sized salads, neutral
#
# Processing query 504 : rack of lamb in black truffle sauce, neutral
#
# Processing query 505 : sauce, positive
#
# Processing query 506 : blueberry pancakes, positive
#
# Processing query 507 : mojitos, positive
#
# Processing query 508 : CRABCAKES, negative
#
# Processing query 509 : setting, positive
#
# Processing query 510 : hotdogs, negative
#
# Processing query 511 : FOOD, positive
#
# Processing query 512 : vintages, negative
#
# Processing query 513 : smoothies, negative
#
# Processing query 514 : margarita, neutral
#
# Processing query 515 : fooood, positive
#
# Processing query 516 : waiter, neutral
#
# Processing query 517 : decor, positive
#
# Processing query 518 : empenadas, positive
#
# Processing query 519 : Chicken McNuggets, positive
#
# Processing query 520 : bread, positive
#
# Processing query 521 : dessert, negative
#
# Processing query 522 : Egg McMuffin sandwich, neutral
#
# Processing query 523 : dessert menu, positive
#
# Processing query 524 : tator tots, positive
#
# Processing query 525 : Odessa stew, positive
#
# Processing query 526 : Focacchia bread, neutral
#
# Processing query 527 : sushi lunch, positive
#
# Processing query 528 : beer list, positive
#
# Processing query 529 : egg, neutral
#
# Processing query 530 : meal, positive
#
# Processing query 531 : menu, negative
#
# Processing query 532 : English muffins, positive
#
# Processing query 533 : fish, negative
#
# Processing query 534 : atmoshere, positive
#
# Processing query 535 : meatball parm, positive
#
# Processing query 536 : outside, negative
# Processing query 537 : chef, neutral
#
# Processing query 538 : repast, positive
#
# Processing query 539 : Chicken Teriyaki, neutral
#
# Processing query 540 : Entrees, neutral
#
# Processing query 541 : Indian food, positive
#
# Processing query 542 : taste, positive
#
# Processing query 543 : sopaipillas, neutral
#
# Processing query 544 : Saag gosht, positive
#
# Processing query 545 : fork, neutral
#
# Processing query 546 : coffee, positive
#
# Processing query 547 : served, neutral
#
# Processing query 548 : entrees, positive
#
# Processing query 549 : king crab salad with passion fruit vinaigrette, positive
#
# Processing query 550 : indian food, positive
#
# Processing query 551 : Pizzas, positive
#
# Processing query 552 : roast chicken, neutral
#
# Processing query 553 : decor, neutral
#
# Processing query 554 : bill, negative
#
# Processing query 555 : MEAL, positive
#
# Processing query 556 : owner, negative
#
# Processing query 557 : rice medley, positive
#
# Processing query 558 : place, negative
#
# Processing query 559 : taramasalata, positive
#
# Processing query 560 : mozzarella sticks, neutral
#
# Processing query 561 : fortune cookies, negative
#
# Processing query 562 : dinner menu, positive
#
# Processing query 563 : rice milk, neutral
#
# Processing query 564 : lamb entree, positive
#
# Processing query 565 : ground chickpea soup, negative
#
# Processing query 566 : meats, negative
#
# Processing query 567 : bottle of wine, neutral
#
# Processing query 568 : homemade sorbets, positive
#
# Processing query 569 : soup, neutral
#
# Processing query 570 : plaintains, positive
#
# Processing query 571 : interior, positive
#
# Processing query 572 : french fries, positive
#
# Processing query 573 : hamburger, positive
#
# Processing query 574 : design, positive
#
# Processing query 575 : mussels, positive
#
# Processing query 576 : Taylor ham, positive
#
# Processing query 577 : Jerusalem market-style falafel wraps, positive
#
# Processing query 578 : ambiance, positive
#
# Processing query 579 : service, neutral
#
# Processing query 580 : hot dog, negative
#
# Processing query 581 : crab cakes, positive
#
# Processing query 582 : Hibiscus lemonade, positive
#
# Processing query 583 : bar, positive
#
# Processing query 584 : wait staff, negative
#
# Processing query 585 : gnocchi, positive
#
# Processing query 586 : martinis, positive
#
# Processing query 587 : served, positive
#
# Processing query 588 : pizza's, positive
#
# Processing query 589 : flavor, negative
#
# Processing query 590 : Coffee, positive
#
# Processing query 591 : cake, negative
#
# Processing query 592 : flavor, positive
#
# Processing query 593 : poori, positive
#
# Processing query 594 : Sangria, positive
#
# Processing query 595 : dining atmosphere, positive
#
# Processing query 596 : beef, positive
#
# Processing query 597 : clientele, negative
#
# Processing query 598 : price, positive
#
# Processing query 599 : bistro menu, neutral
#
# Processing query 600 : soft shell crab sandwich with fries, positive
#
# Processing query 601 : pie, neutral
#
# Processing query 602 : room, negative
#
# Processing query 603 : eggplant salad, positive
#
# Processing query 604 : chocolate raspberry cake, positive
#
# Processing query 605 : late lunch, neutral
#
# Processing query 606 : bartenders, positive
#
# Processing query 607 : spices, positive
#
# Processing query 608 : gratuity, negative
#
# Processing query 609 : burrito, positive
#
# Processing query 610 : fresh juice concoctions, positive
#
# Processing query 611 : homemade Guacamole, positive
#
# Processing query 612 : Waiting, negative
#
# Processing query 613 : fettuccine with grilled seafood in a rosemary-orange sauce, positive
#
# Processing query 614 : grand marnier shrimp, positive
#
# Processing query 615 : delivery times, positive
#
# Processing query 616 : salads, neutral
#
# Processing query 617 : dinner specials, positive
#
# Processing query 618 : sushi/sashimi, neutral
#
# Processing query 619 : billed, negative
#
# Processing query 620 : ITALIAN MEAL, neutral
#
# Processing query 621 : cuisine, positive
#
# Processing query 622 : waiting, negative
#
# Processing query 623 : texture, positive
#
# Processing query 624 : rolls with crab, positive
#
# Processing query 625 : Sushi, positive
#
# Processing query 626 : meals, negative
#
# Processing query 627 : Mediterranean salads--layered with beets, goat cheese and walnuts, positive
#
# Processing query 628 : casual lunches, neutral
#
# Processing query 629 : brunch menu, positive
#
# Processing query 630 : non-meat alternatives, neutral
#
# Processing query 631 : quesedilla, neutral
#
# Processing query 632 : grilled cheeses, positive
#
# Processing query 633 : downstairs bar scene, positive
#
# Processing query 634 : service, negative
#
# Processing query 635 : Japanese food, positive
#
# Processing query 636 : milkshakes, positive
#
# Processing query 637 : interior, negative
#
# Processing query 638 : Sandwiches, positive
#
# Processing query 639 : french food, positive
#
# Processing query 640 : entree, neutral
#
# Processing query 641 : Food, positive
